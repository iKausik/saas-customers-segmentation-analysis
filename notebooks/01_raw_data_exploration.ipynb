# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../data/raw/raw_customer_data.csv')

# %%
print("Null values in each column:\n")
print(df.isnull().sum())
print("\nDuplicate rows in the DataFrame:\n")
print(df.duplicated().sum())
print("\nFirst 10 rows of the DataFrame:\n")
print(df.head(10))
print("\nInfo about the DataFrame:\n")
print(df.info())
print("\nDescriptive statistics of the DataFrame:\n")
print(df.describe())
# Out:
# Null values in each column:
#
# customer_id            0
# signup_date            0
# last_active_date       0
# subscription_plan      0
# monthly_spend          0
# support_tickets        0
# logins_last_30_days    0
# feature_usage_score    0
# industry               0
# team_size              0
# is_churned             0
# dtype: int64
#
# Duplicate rows in the DataFrame:
#
# 0
#
# First 10 rows of the DataFrame:
#
#   customer_id signup_date last_active_date subscription_plan  monthly_spend  \
# 0  CUST100000  2022-02-13       2024-04-10             Basic          18.01
# 1  CUST100001  2022-09-20       2024-04-27        Enterprise         468.68
# 2  CUST100002  2021-06-03       2024-04-30               Pro          52.02
# 3  CUST100003  2021-12-12       2024-04-07               Pro          54.96
# 4  CUST100004  2022-08-17       2024-04-22             Basic          19.98
# 5  CUST100005  2021-07-23       2024-04-23             Basic          19.17
# ...

# %%
# change data types
df['subscription_plan'] = df['subscription_plan'].astype('category')
df['industry'] = df['industry'].astype('category')
df['is_churned'] = df['is_churned'].astype('bool')
df['signup_date'] = pd.to_datetime(df['signup_date'])
df['last_active_date'] = pd.to_datetime(df['last_active_date'])

print("\nData types after conversion:\n")
print(df.info())
# Out:
# Data types after conversion:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   customer_id          40000 non-null  object
#  1   signup_date          40000 non-null  datetime64[ns]
#  2   last_active_date     40000 non-null  datetime64[ns]
#  3   subscription_plan    40000 non-null  category
#  4   monthly_spend        40000 non-null  float64
#  5   support_tickets      40000 non-null  int64
#  6   logins_last_30_days  40000 non-null  int64
#  7   feature_usage_score  40000 non-null  float64
#  8   industry             40000 non-null  category
#  9   team_size            40000 non-null  int64
#  10  is_churned           40000 non-null  bool
# dtypes: bool(1), category(2), datetime64[ns](2), float64(2), int64(3), object(1)
# memory usage: 2.6+ MB
# None

# %%
print("Latest Signup date:", df['signup_date'].max())
print("Earlier Signup date:", df['signup_date'].min())

print("Latest active date:", df['last_active_date'].max())
print("Earlier active date:", df['last_active_date'].min())

print(df['is_churned'].value_counts())
# Out:
# Latest Signup date: 2024-03-31 00:00:00
# Earlier Signup date: 2021-04-01 00:00:00
# Latest active date: 2024-04-30 00:00:00
# Earlier active date: 2021-05-11 00:00:00
# is_churned
# False    31959
# True      8041
# Name: count, dtype: int64
